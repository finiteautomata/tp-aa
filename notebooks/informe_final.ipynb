# %% [markdown]
# # Informe TP1 Aprendizaje automático
#
# All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy.All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy. All work and no play makes Jack a dull boy, All play and no work makes Jack a mere toy.

# %%
1+1 == 2
# Out:
# True
